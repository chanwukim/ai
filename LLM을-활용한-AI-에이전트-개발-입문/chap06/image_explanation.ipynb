# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

messages = [
    {
    "role": "user",
    "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해 주세요."},
            {"type": "image_url", "image_url": {"url": "https://images.unsplash.com/photo-1752328618119-8805f8a9ff19?ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&fit=crop&q=80&w=987"}}
        ]
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response
# Out:
# ChatCompletion(id='chatcmpl-CXrEfTbbDGIgQHnXal6r2dCQGiRdE', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이 이미지에는 초원에 여러 마리의 얼룩말이 모여 있는 모습을 담고 있습니다. 얼룩말들은 풀밭 속에 서 있으며, 주변에는 나무들이 몇 그루 보입니다. 밝은 하늘이 배경을 이루고 있으며, 자연 속에서 얼룩말들이 평화롭게 있는 장면입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1762185497, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_cbf1785567', usage=CompletionUsage(completion_tokens=75, prompt_tokens=1120, total_tokens=1195, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
import base64

def encode_image(image_path: str) -> str:
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_path = "./photo.jpeg"
image_base64 = encode_image(image_path)

print(image_base64)
# Out:
# ...

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{image_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response.choices[0].message.content
# Out:
# '이 이미지에는 여러 마리의 얼룩말이 풀밭에 서 있는 모습이 담겨 있습니다. 배경에는 몇 그루의 나무가 서 있는 것을 볼 수 있으며, 전형적인 사바나 풍경입니다. 얼룩말들은 초원을 배경으로 자연스럽게 어우러져 있으며, 사진은 고요한 자연의 한 장면을 포착하고 있습니다.'

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "두 이미지의 차이점을 설명해주세요"},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{image_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{image_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response.choices[0].message.content
# Out:
# '두 이미지의 차이점을 찾을 수 없습니다. 두 이미지는 동일해 보입니다. 특히 동일한 배경과 얼룩말들이 있습니다.'
